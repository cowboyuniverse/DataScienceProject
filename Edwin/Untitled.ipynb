# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

from numpy import array
from sklearn.linear_model import LogisticRegression

# %%
cuisine_train_dataframe = pd.read_json('../35000.json')

def string_to_numerical(x):    
    return pd.Series(x)


cuisine_train_dataframe['ingredients'] = cuisine_train_dataframe['ingredients'].apply(string_to_numerical)


cuisine_train_dataframe=pd.get_dummies(cuisine_train_dataframe,
                                       columns=["ingredients"],drop_first=False)

new_features = list(cuisine_train_dataframe.dtypes.index)
new_features.remove('cuisine')

X = cuisine_train_dataframe[new_features]

print(new_features)
# Out:
# ['id', 'ingredients_(    oz.) tomato sauce', 'ingredients_(14.5 oz.) diced tomatoes', 'ingredients_1% low-fat buttermilk', 'ingredients_1% low-fat cottage cheese', 'ingredients_1% low-fat milk', 'ingredients_2% reduced-fat milk', 'ingredients_40% less sodium taco seasoning', 'ingredients_Accent Seasoning', 'ingredients_Alfredo sauce', 'ingredients_American cheese', 'ingredients_Anaheim chile', 'ingredients_Angostura bitters', 'ingredients_BACARDIÂ® Mixers Margarita Mix', 'ingredients_Baileys Irish Cream Liqueur', 'ingredients_Bartlett Pear', 'ingredients_Belgian endive', 'ingredients_BertolliÂ® Classico Olive Oil', 'ingredients_Biryani Masala', 'ingredients_Boston lettuce', "ingredients_Campbell's Condensed Cheddar Cheese Soup", "ingredients_Campbell's Condensed Cream of Mushroom Soup", "ingredients_Campbell's Condensed Tomato Soup", 'ingredients_Chambord Liqueur', 'ingredients_Chianti', 'ingredients_Cointreau Liqueur', 'ingredients_Conimex Wok Olie', 'ingredients_Daisy Sour Cream', 
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

y = cuisine_train_dataframe['cuisine'] 


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

logReg = LogisticRegression()
logReg.fit(X_train, y_train)

y_predict = logReg.predict(X_test)

# print(y_predict)
# print(y_test) 

accuracy = accuracy_score(y_test, y_predict)

print("\nAccuracy: ", accuracy)
# Out:
# Accuracy:  0.196571428571
